# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input'] = [1,1,0,0]
or_data['input2'] = [1,0,1,0]
or_data['output'] = [1,1,1,0]

# %%
and_data['input'] = [1,1,0,0]
and_data['input2'] = [1,0,1,0]
and_data['output'] = [1,0,0,0]

# %%
xor_data['input'] = [1,1,0,0]
xor_data['input2'] = [1,0,1,0]
xor_data['output'] = [0,1,1,0]

# %%
and_data
# Out:
#    input  input2  output
# 0      1       1       1
# 1      1       0       0
# 2      0       1       0
# 3      0       0       0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# and_data['input'].plot(kind='hist', bins=20, title='input')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# and_data['input2'].plot(kind='hist', bins=20, title='input2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# and_data['output'].plot(kind='hist', bins=20, title='output')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
or_data
# Out:
#    input  input2  output
# 0      1       1       1
# 1      1       0       1
# 2      0       1       1
# 3      0       0       0

# %%
xor_data
# Out:
#    input  input2  output
# 0      1       1       0
# 1      1       0       1
# 2      0       1       1
# 3      0       0       0

# %%
sns.scatterplot(data=and_data, x = "input", y= "input2", hue = "output",s = 150)
# Out:
# <Axes: xlabel='input', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:,:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
Perceptron(alpha=0.0001, class_weight = None, early_stopping = False, eta0 = 1.0,
           fit_intercept = True, max_iter = 1000, n_iter_no_change=5, n_jobs = None,
           penalty = None, random_state = 0, shuffle=True, tol = 0.001,
           validation_fraction = 0.1, verbose = 0, warm_start = False)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x = np.linspace(-1,1,5)
y = -x+1

# %%
plt.plot(x,y)
sns.scatterplot(x = "input", y = "input2", hue= "output", data = and_data, s = 200)
# Out:
# <Axes: xlabel='input', ylabel='input2'>

# %%
clf2.coef_
clf2.intercept_
# Out:
# array([-1.])

# %%
x1 = np.linspace(-1,1,5)
y1 = -x + 0.5

# %%
plt.plot(x1,y1)

sns.scatterplot(x="input", y="input2", hue="output", data=or_data, s=200)
# Out:
# <Axes: xlabel='input', ylabel='input2'>

# %%
clf3.coef_
clf3.intercept_
# Out:
# array([0.])

# %%
x2=np.linspace(-1,1,5)
y2=-x+0.5

# %%
plt.plot(x2,y2)

sns.scatterplot(x="input", y="input2", hue="output", data=xor_data, s=200)
# Out:
# <Axes: xlabel='input', ylabel='input2'>

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
# Out:
# <Axes: >
