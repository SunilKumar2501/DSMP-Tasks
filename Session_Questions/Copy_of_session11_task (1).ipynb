# %% [markdown]
# ## Exception Handling

# %% [markdown]
# ###`Q-1`: You are given a function definition. There might be several issues on execution of this function. You are asked to do exception handling for diffrent errors that this function goes in to `without altering this function`. And print error text.

# %% [markdown]
# Function parameters `l -> list, s -> could be anything`
#
# ```
# def function(l: list, s, **args):
#     last_element = l[-1]
#
#     l[int(s)]=10
#     any_element = l[int(s)+10]
#     l[s]=10
#
#     res = sum(l)
#
#     p = args['p']
#     # print(p)
#     return res/last_element * p + any_element
#
# ```
# Check for different function calls:-
#
# ```
# function([1,2,1], 12)
# function([1,2,1]*9, '1-2')
# function([1,'2',1]*9, 12)
# function([1,'2',1]*9, 12)
# function([1,2,0]*9, 12  )
# function([1,2,1]*9, 12, p=None)
# function([1,2,0]*9, 12, p=10)
# ```

# %%
def function(l: list, s, **args):
    last_element = l[-1]
    l[int(s)]=10
    any_element = l[int(s)+10]
    l[s]=10

    res = sum(l)

    p = args['p']
    # print(p)
    return res/last_element * p + any_element


try:
  function([1,2,1], 12)
except IndexError as e:
  print(type(e))
  print(e)

try:
  function([1,2,1]*9, '1-2')
except ValueError as v:
  print(type(v))
  print(v)

try:
  function([1,'2',1]*9, 12)
except TypeError as v:
  print(type(v))
  print(v)

try:
  function([1,2,0]*9, 12  )
except KeyError as v:
  print(type(v))
  print(v)

try:
  function([1,2,0]*9,12, p = None  )
except ZeroDivisionError as v:
  print(type(v))
  print(v)

try:
  function([1,2,0]*9, 12, p=10)
except ZeroDivisionError as v:
  print(type(v))
  print(v)
try:
  res = function([1,2,1]*9, 12, p = 10)
except Exception as e:
  print(e)
else:
  print("Result:",res)
finally:
  print("thank you")
# Out:
# <class 'IndexError'>
# list assignment index out of range
# <class 'ValueError'>
# invalid literal for int() with base 10: '1-2'
# <class 'TypeError'>
# unsupported operand type(s) for +: 'int' and 'str'
# <class 'KeyError'>
# 'p'
# <class 'ZeroDivisionError'>
# division by zero
# <class 'ZeroDivisionError'>
# division by zero
# Result: 452.0
# thank you

# %% [markdown]
# ###`Q-2:` You are given a code snippet. There might be several issues on execution of this code. You are asked to do exception handling for diffrent errors, condition is what ever happens we need to execute last line printing correct result of `sum of elements`.
#
# List have elemnts as any no of  `key-pair dict with key as list index and value as any integer`, `integers` and `numeric-strings`. There is always only one element in the dict.
#
#
# ```
# l = [{0:2},2,3,4,'5', {5:10}]
# # For calculating sum of above list
# s=0
# for i in range(len(l)):
#     #You can Edit code from here
#     s += l[i].get(i)
#     s += l[i]
#     s += int(l[i])
#
#
# print(s)
# ```

# %%
l = [{0:2},2,3,4,'5', {5:10}]
# For calculating sum of above list
s=0
for i in range(len(l)):
    #You can Edit code from here
    try:
      s += l[i]
    except TypeError:
      try:
        s += l[i].get(i)
      except AttributeError:
        s += int(l[i])



print(s)
# Out:
# 26

# %% [markdown]
# ### `Q-3:`: File Handling with Exception handling
#
# Write a program that opens a text file and write data to it as "Hello, Good Morning!!!". Handle exceptions that can be generated during the I/O operations. Do not show the success message on the main exception handling block (write inside the else block).

# %%
try:
  with open("sample.txt","w") as f:
    f.write("Hello, Good Morning!!!")
except IOError:
  print("File not Created")
else:
  print("File created sucessfully")
  with open("sample.txt",'r') as r:
    print(r.read())
# Out:
# File created sucessfully
# Hello, Good Morning!!!

# %% [markdown]
# ### `Q-4`: Number game program.
#
# Write a number game program. Ask the user to enter a number. If the number is greater than number to be guessed, raise a **ValueTooLarge** exception. If the value is smaller the number to be guessed the, raise a **ValueTooSmall** exception and prompt the user to enter again. Quit the program only when the user enters the correct number. Also raise **GuessError** if user guess a number less than 1.

# %%
import random

class GuessError(Exception):
  def display(self):
    print("Value is less then 1")

class ValueTooLarge(Exception):
  def display(self):
    print("Value is larger than answer")

class ValueTooSmall(Exception):
  def display(self):
    print("Value is smaller than answer")


random_num = random.randint(1,100)
# print(random_num)
while True:
  try:
    guess = int(input("Enter the number: "))
    if(guess == random_num):
      print("Right Answer")
      break

    elif (guess < 1):
      raise GuessError

    elif(guess > random_num):
     raise ValueTooLarge

    elif(guess < random_num):
      raise ValueTooSmall



  except ValueTooSmall as v:
    v.display()

  except ValueTooLarge as s:
    s.display()

  except GuessError as v:
    v.display()
# Out:
# Enter the number: 4
# Value is smaller than answer
# Enter the number: 50
# Value is smaller than answer
# Enter the number: 60
# Value is smaller than answer
# Enter the number: 80
# Value is smaller than answer
# Enter the number: 90
# Value is larger than answer
# Enter the number: 85
# Value is smaller than answer
# Enter the number: 88
# Value is larger than answer
# Enter the number: 86
# Value is smaller than answer
# Enter the number: 87
# Right Answer

# %% [markdown]
# ### `Q-5:` Cast vote
#
# Write a program that validate name and age as entered by the user to determine whether the person can cast vote or not. To handle the age, create **InvalidAge** exception and for name, create **InvalidName** exception. The name will be invalid when the string will be empty or name has only one word.
#
# Example 1:
#
# Input:
#
# ```bash
# Enter the name:               goransh singh
# Enter the age: 25
# ```
#
# Output:
#
# ```bash
# Goransh Singh  Congratulation !!! You can vote.
# ```

# %%
class Invalid_age(Exception):
  def display(self):
    print("Invalid Age")

class Invalid_name(Exception):
  def display(self):
    print("Invalid Name")

def voting_right(name,age):
  try:
    if(name == "" and len(name) < 2):
      raise Invalid_name
    elif (age < 18):
      raise Invalid_age
  except Invalid_name as i:
    i.display()
  except Invalid_age as a:
    a.display()

  else:
    print( name," Congratulation !!!, Your are qualified for voating")
  finally:
    print("Thank you")

voting_right("Sunil kumar",20)
# Out:
# Sunil kumar  Congratulation !!!, Your are qualified for voating
# Thank you

# %% [markdown]
# ### `Q-6`: Write a python function which infinitely prints natural numbers in a single line. Raise the **StopIteration** exception after displaying first 20 numnbers to exit from the program.

# %%
def natural_num(n):
  i = 0
  l = []
  try:
    while True:
      n = n + 1
      i = i +1
      l.append(n)
      if (i == 20):
        raise StopIteration
  except StopIteration as s:
    print(l)
    exit()

natural_num(100)
# Out:
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120]

# %%
def natural_num(n):
  i = 0
  l = []

  while True:
    try:
      n = n + 1
      i = i +1
      l.append(n)
      if (i == 21):
        raise StopIteration
    except StopIteration as s:
      break
    else:
      print(n,end = " ")

natural_num(100)
# Out:
# 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117 118 119 120
