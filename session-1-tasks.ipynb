# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
print("Data", "Science", "Mentorship" ,"Program","Started" ,
"By" ,"CampusX", sep = "-")
# Out:
# Data-Science-Mentorship-Program-Started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
celcius = int(input("Enter the value :"))
fahren = (celcius * (9/5) + 32)
print(fahren)
# Out:
# Enter the value :45
# 113.0

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a = int(input("a : "))
b = int (input("b : "))
temp=b
b = a
a = temp
print(a,b);
# Out:
# a : 4
# b : 5
# 5 4

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
x1 = int(input("X1 : "))
x2 = int(input("X2 : "))
y1 = int(input("Y1 : "))
y2 = int(input("Y2 : "))
import math
Euclidean = (x2-x1)**2 + (y2 - y16)**2
print(math.sqrt(Euclidean))
# Out:
# X1 : 5
# X2 : 4
# Y1 : 6
# Y2 : 7
# 1.4142135623730951

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
principle = int(input("Principle : "))
interest = int(input("Interest : "))
time = int(input("Time : "))
SI = principle * interest * time
print(SI/100)
# Out:
# Principle : 10000
# Interest : 10
# Time : 10
# 10000.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
heads = int(input("Number of heads : "))
legs = int(input("Number of heads : "))
dogs = (legs - 2 * heads) // 2
chickens = heads - dogs
print("dogs -> ",dogs)
print("chickens -> ",chickens)
# Out:
# Number of heads4
# Number of heads12
# dogs ->  2
# chickens ->  2

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input("Enter the number : "))
if(n<=0):
  print("Not a valid natural number")
else:
  square_sum = 0;
  for i in range (1,n+1):
    square_sum += i**2
  print("Sum of squares of the first", n, "natural numbers:", square_sum)
# Out:
# Enter the number : 5
# Sum of squares of the first 5 natural numbers: 55

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
a1 = int(input("Enter the number : "))
a2= int(input("Enter the number : "))
nth = int(input("Enter the number : "))
d = a2-a1
an = a1 + (nth -1)*d
print(an)
# Out:
# Enter the number : 2
# Enter the number : 4
# Enter the number : 10
# 20

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
num1 = int(input("numenator 1 : "))
num2 = int(input("numenator 2 : "))
dem1 = int(input("denominator 1 : "))
dem2 = int(input("denominator 2 : "))

sum1 = num1 * dem2 + num2*dem1
product = dem1 * dem2
print(sum1/product)
# Out:
# numenator 1 : 1
# numenator 2 : 3
# denominator 1 : 2
# denominator 2 : 4
# 1.25

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
height = int(input())
length = int(input())
breadth = int(input())

heightglass = int(input())
radius = int(input())

volume1 = height * length * breadth
volume2 = 22/7*radius**2 * heightglass

print("The number of glass needed are :" ,volume1 // volume2)
# Out:
# 20
# 20
# 20
# 3
# 1
# The number of glass needed are : 848.4848484848485
